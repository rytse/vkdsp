# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = scipy.fromfile(open("../tmp.bin"), dtype=scipy.complex64)
plt.plot(np.abs(x))
plt.show()
plt.plot(np.abs(np.fft.fft(x)))
plt.show()
# Out:
# /home/rytse/anaconda3/envs/vkdsp/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: scipy.fromfile is deprecated and will be removed in SciPy 2.0.0, use numpy.fromfile instead
#   """Entry point for launching an IPython kernel.

# %%
df = pd.read_csv("../test.csv", header=None)
x_rs_spec =  np.array(df.iloc[:,0], np.complex)
plt.plot(np.abs(x_rs_spec))
plt.show()
